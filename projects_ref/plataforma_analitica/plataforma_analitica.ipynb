# %% [markdown]
# # 1 - Usuários e Acessos

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2 - Tipos de projeto que vão pra produção

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3 - Hadoop Cluster Architecture

# %% [markdown]
# ![image.png](attachment:image.png)
