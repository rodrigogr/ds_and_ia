# %% [markdown]
# # 1 - Introdução
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2 - PPS (Predictive Power Score)
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3 - Seleção de Features
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4 - Detecção de Overfitting
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5 - Regularização
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6 - Shapley Values
# ![image.png](attachment:image.png)
